# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
AMD = pd.read_excel('C:\\Users\\CHIDIEBERE NNAMANI\\Documents\\ENTRY-LEVEL DOCUMENTS\\AFRICAN MOBILE DATA\\African Mobile Data.xlsx')
AMD.head()

# %%
sns.stripplot(AMD['Segment'], AMD['Profit'])

# %%
sns.distplot(AMD['Sales'])

# %%
sns.distplot(AMD['Profit'])

# %%
sns.barplot(AMD['Region'], AMD['Sales'])

# %%
sns.jointplot(AMD['Profit'], AMD['Sales'])

# %%
sns.pairplot(AMD[['Profit','Sales','PROFIT/LOSS']])

# %%
sns.boxplot(AMD['Sales'], AMD['Profit'], hue=AMD['PROFIT/LOSS'])

# %%
sns.countplot(AMD['Region'])

# %%
sns.pointplot(AMD['Sales'], AMD['Profit'], hue=AMD['PROFIT/LOSS'])

# %%
sns.barplot(AMD['Region'], AMD['Profit'])

# %%
AMD.loc[AMD['Region'] == 'Western']
AMD_Western = AMD.loc[AMD['Region'] == 'Western']
AMD_Western

# %%
sns.barplot(AMD_Western['Country'], AMD_Western['Profit'])

# %%
AMD.loc[AMD['Region'] == 'Northern']
AMD_Northern = AMD.loc[AMD['Region'] == 'Northern']
AMD_Northern

# %%
sns.barplot(AMD_Northern['Country'], AMD_Northern['Profit'])
