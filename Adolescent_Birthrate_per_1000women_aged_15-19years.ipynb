# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
AB = pd.read_excel('C:\\Users\\CHIDIEBERE NNAMANI\\Documents\\Adolescent birthrate files\\Adolescent birthrate data.xlsx')
AB.columns
# Out:
# Index(['Year (string)', 'WHO region (string)', 'Country (string)',
#        'Age Group (string)', 'Sex (string)',
#        'Adolescent birth rate (per 1000 women aged 15-19 years) (string)'],
#       dtype='object')

# %%
sns.countplot(AB['WHO region (string)'])
